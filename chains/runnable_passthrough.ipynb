# %%
from langchain_groq import ChatGroq
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough,RunnableParallel,RunnableSequence
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
model=ChatGroq(model="moonshotai/kimi-k2-instruct-0905")
promt1=PromptTemplate(template="tell me a frictional joke about {topic}",
                      input_variables=["topic"])
promt2=PromptTemplate(template="explain the input {text}",
                      input_variables=["text"])
parsor=StrOutputParser()

# %%
sequential_chain=promt1|model|parsor

# %%
parallel_chain=RunnableParallel({
    'joke':RunnablePassthrough(),
    "explanation": RunnableSequence(promt2|model|parsor)
})

# %%
final_chain=sequential_chain|parallel_chain
final_chain.invoke({'topic':"human"})
# Out:
# {'joke': 'Why did the human apply for a job as a haunted-house actor?\n\nBecause they finally found a place where their *existential dread* was considered a *professional skill*.',
#  'explanation': 'Why did the human apply for a job as a haunted-house actor?\n\nBecause after years of practice waking up at 3 a.m. to stare at the ceiling and whisper “What if none of this matters?” they figured ghosts were basically just HR with better lighting.'}
